# %% [markdown]
# ## 練習時間
# 資料的操作有很多，接下來的馬拉松中我們會介紹常被使用到的操作，參加者不妨先自行想像一下，第一次看到資料，我們一般會想知道什麼訊息？
#
# #### Ex: 如何知道資料的 row 數以及 column 數、有什麼欄位、多少欄位、如何截取部分的資料等等
#
# 有了對資料的好奇之後，我們又怎麼通過程式碼來達成我們的目的呢？
#
# #### 可參考該[基礎教材](https://bookdata.readthedocs.io/en/latest/base/01_pandas.html#DataFrame-%E5%85%A5%E9%97%A8)或自行 google

# %%
import os
import numpy as np
import pandas as pd

# %%
# 設定 data_path
dir_data = '../data/Part01/'

# %%
f_app = os.path.join(dir_data, 'application_train.csv')
print('Path of read in data: %s' % (f_app))

app_train = pd.read_csv(f_app)    # 讀取 CSV 檔案
# Out:
# Path of read in data: ../data/Part01/application_train.csv

# %%
'''
app_train 為 DataFrame 物件
'''
app_train.info()        # Print a concise summary of a DataFrame

print('*'*120)
print('DataFrame 資料組成示意圖：')
from IPython.display import Image
Image(filename='../resources/base_01_pandas_5_0.png', width=800)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Columns: 122 entries, SK_ID_CURR to AMT_REQ_CREDIT_BUREAU_YEAR
# dtypes: float64(65), int64(41), object(16)
# memory usage: 286.2+ MB
# ************************************************************************************************************************
# DataFrame 資料組成示意圖：

# %% [markdown]
# ### 如果沒有想法，可以先嘗試找出剛剛例子中提到的問題的答案
# #### 資料的 row 數以及 column 數

# %%
'''
方法1
app_train.columns       # 會回傳所有欄位名稱(索引名稱、項目)
app_train.index         # 會回傳所有列的索引項目，是一個 <class 'pandas.core.indexes.range.RangeIndex'> 物件
'''
print('column count:', len(app_train.columns))
print('row count:', len(app_train.index))
# Out:
# column count: 122
# row count: 307511

# %%
'''
方法2
透過使用 app_train.shape 方法來取得資料表格的尺寸(tuple)資訊，
'''
(rows, cols) = app_train.shape

print('column count:', cols)
print('row count:', rows)
# Out:
# column count: 122
# row count: 307511

# %% [markdown]
# #### 列出所有欄位

# %%
col_width = len(max(app_train.columns, key=len))
print('max column name length:', col_width, '\n')

cc = 0; item_per_line = 4;
colstr=""
for c in app_train.columns:
    colstr += "{:<30}".format(c)
    cc+=1
    if(cc % item_per_line == 0):
        print(colstr)
        colstr=""
# Out:
# max column name length: 28
#
# SK_ID_CURR                    TARGET                        NAME_CONTRACT_TYPE            CODE_GENDER
# FLAG_OWN_CAR                  FLAG_OWN_REALTY               CNT_CHILDREN                  AMT_INCOME_TOTAL
# AMT_CREDIT                    AMT_ANNUITY                   AMT_GOODS_PRICE               NAME_TYPE_SUITE
# NAME_INCOME_TYPE              NAME_EDUCATION_TYPE           NAME_FAMILY_STATUS            NAME_HOUSING_TYPE
# REGION_POPULATION_RELATIVE    DAYS_BIRTH                    DAYS_EMPLOYED                 DAYS_REGISTRATION
# DAYS_ID_PUBLISH               OWN_CAR_AGE                   FLAG_MOBIL                    FLAG_EMP_PHONE
# FLAG_WORK_PHONE               FLAG_CONT_MOBILE              FLAG_PHONE                    FLAG_EMAIL
# OCCUPATION_TYPE               CNT_FAM_MEMBERS               REGION_RATING_CLIENT          REGION_RATING_CLIENT_W_CITY
# ...

# %% [markdown]
# #### 截取部分資料

# %%
'''
使用 app_train.head(n) 來取的頭幾筆資料，n 預設值為 5。
'''
app_train.head(15)
# Out:
#     SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0       100002       1         Cash loans           M            N
# 1       100003       0         Cash loans           F            N
# 2       100004       0    Revolving loans           M            Y
# 3       100006       0         Cash loans           F            N
# 4       100007       0         Cash loans           M            N
# 5       100008       0         Cash loans           M            N
# 6       100009       0         Cash loans           F            Y
# 7       100010       0         Cash loans           M            Y
# 8       100011       0         Cash loans           F            N
# 9       100012       0    Revolving loans           M            N
# 10      100014       0         Cash loans           F            N
# 11      100015       0         Cash loans           F            N
# 12      100016       0         Cash loans           F            N
# ...

# %% [markdown]
# #### 還有各種數之不盡的資料操作，重點還是取決於實務中遇到的狀況和你想問的問題，在馬拉松中我們也會陸續提到更多例子

# %%
'''
查看最後 n 筆資料
'''

app_train.tail(6)
# Out:
#           SKID  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 307505  456249       0         Cash loans           F            N
# 307506  456251       0         Cash loans           M            N
# 307507  456252       0         Cash loans           F            N
# 307508  456253       0         Cash loans           F            N
# 307509  456254       1         Cash loans           F            N
# 307510  456255       0         Cash loans           F            N
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 307505               Y             0          112500.0    225000.0
# 307506               N             0          157500.0    254700.0
# 307507               Y             0           72000.0    269550.0
# 307508               Y             0          153000.0    677664.0
# 307509               Y             0          171000.0    370107.0
# 307510               N             0          157500.0    675000.0
#
# ...

# %%
'''
column 也是一個 Series
'''
cidx = app_train.columns     # 取得行索引物件
        # app_train.columns.tolist()           # 將資料轉換為 list
ridx = app_train.index       # 取得列索引物件

# 取得指定欄位序列值
app_train.AMT_INCOME_TOTAL      # 把欄位名稱當作屬性使用，取得該欄位的所有列值，即 取得該欄的 序列值(Serial)
# app_train['AMT_INCOME_TOTAL']   # 等價使用方式
# Out:
# 0         202500.000
# 1         270000.000
# 2          67500.000
# 3         135000.000
# 4         121500.000
# 5          99000.000
# 6         171000.000
# 7         360000.000
# 8         112500.000
# 9         135000.000
# 10        112500.000
# 11         38419.155
# 12         67500.000
# 13        225000.000
# 14        189000.000
# 15        157500.000
# 16        108000.000
# 17         81000.000
# 18        112500.000
# 19         90000.000
# 20        135000.000
# 21        202500.000
# 22        450000.000
# 23         83250.000
# 24        135000.000
# 25         90000.000
# 26        112500.000
# 27        112500.000
# 28        270000.000
# 29         90000.000
#              ...
# 307481    225000.000
# 307482    225000.000
# 307483     99000.000
# 307484    540000.000
# 307485    270000.000
# 307486    292500.000
# 307487    117000.000
# 307488    157500.000
# 307489    225000.000
# 307490     81000.000
# 307491     90000.000
# 307492    585000.000
# ...

# %%
# 欄位名稱變更
app_train.rename(columns={'SK_ID_CURR':'SKID'}, inplace=True)

# 取得指定欄號的名稱，即欄位名稱
print('new column name:', app_train.columns[0])          # 會顯示修改後的新名稱

# 取得指定欄位名稱的序列資料
print(app_train.SKID)
# Out:
# new column name: SKID
# 0         100002
# 1         100003
# 2         100004
# 3         100006
# 4         100007
# 5         100008
# 6         100009
# 7         100010
# 8         100011
# 9         100012
# 10        100014
# 11        100015
# 12        100016
# 13        100017
# 14        100018
# 15        100019
# 16        100020
# 17        100021
# 18        100022
# 19        100023
# 20        100024
# 21        100025
# 22        100026
# 23        100027
# 24        100029
# 25        100030
# 26        100031
# 27        100032
# 28        100033
# 29        100034
#            ...
# 307481    456225
# 307482    456226
# 307483    456227
# 307484    456228
# 307485    456229
# 307486    456230
# 307487    456231
# 307488    456232
# 307489    456233
# 307490    456234
# 307491    456235
# 307492    456236
# 307493    456237
# 307494    456238
# 307495    456239
# 307496    456240
# 307497    456241
# 307498    456242
# 307499    456243
# 307500    456244
# ...

# %%
'''
計算所有欄位中，資料序列非 null, `None`, `NaN`, `NaT` 的個數
參數 axis 為統計方式， 0 以欄統計(預設)；1 以列來統計
''' 
print(app_train.count())        # 列出所有欄位的統計資料

print('-'*120)

# 指定取得指定的欄位資料個數值
print('column "AMT_REQ_CREDIT_BUREAU_HOUR" data count:', app_train['AMT_REQ_CREDIT_BUREAU_HOUR'].count())
# Out:
# SKID                          307511
# TARGET                        307511
# NAME_CONTRACT_TYPE            307511
# CODE_GENDER                   307511
# FLAG_OWN_CAR                  307511
# FLAG_OWN_REALTY               307511
# CNT_CHILDREN                  307511
# AMT_INCOME_TOTAL              307511
# AMT_CREDIT                    307511
# AMT_ANNUITY                   307499
# AMT_GOODS_PRICE               307233
# NAME_TYPE_SUITE               306219
# NAME_INCOME_TYPE              307511
# NAME_EDUCATION_TYPE           307511
# NAME_FAMILY_STATUS            307511
# NAME_HOUSING_TYPE             307511
# REGION_POPULATION_RELATIVE    307511
# DAYS_BIRTH                    307511
# DAYS_EMPLOYED                 307511
# DAYS_REGISTRATION             307511
# DAYS_ID_PUBLISH               307511
# OWN_CAR_AGE                   104582
# FLAG_MOBIL                    307511
# FLAG_EMP_PHONE                307511
# FLAG_WORK_PHONE               307511
# ...

# %%
'''
資料表操作
'''

print(app_train.iloc[3])                   # 取得指定索引號的列資料

new_app_train = app_train.drop(3)          # 刪除指定索引的列資料
                                           #   然後會回傳一個新的 DataFrame
print('-'*120)
print(new_app_train.iloc[3])
# Out:
# SKID                                                 100006
# TARGET                                                    0
# NAME_CONTRACT_TYPE                               Cash loans
# CODE_GENDER                                               F
# FLAG_OWN_CAR                                              N
# FLAG_OWN_REALTY                                           Y
# CNT_CHILDREN                                              0
# AMT_INCOME_TOTAL                                     135000
# AMT_CREDIT                                           312682
# AMT_ANNUITY                                         29686.5
# AMT_GOODS_PRICE                                      297000
# NAME_TYPE_SUITE                               Unaccompanied
# NAME_INCOME_TYPE                                    Working
# NAME_EDUCATION_TYPE           Secondary / secondary special
# NAME_FAMILY_STATUS                           Civil marriage
# NAME_HOUSING_TYPE                         House / apartment
# ...

# %%
'''
# 資料切片
取得指定行列索引號的資料
''' 

print(app_train.iloc[4:7,0:3])     # 取得第 4~6 列的資料，並只有顯示 0~2 個欄位

Image(filename='../resources/Pandas-selections-and-indexing-768x549.png', width=600)
# Out:
#      SKID  TARGET NAME_CONTRACT_TYPE
# 4  100007       0         Cash loans
# 5  100008       0         Cash loans
# 6  100009       0         Cash loans

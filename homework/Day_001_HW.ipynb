# %% [markdown]
# # 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# > 選取題目：Google Landmark Recognition 2019
#
# 1. 你選的這組資料為何重要
# > 答：使用者每日可能都會從行動裝置拍攝大量影像，若能夠及時識別標示影像內的地標或是地點，就可以省去照片整理時間，也可以立即搜尋。
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# > 答：Google提供的 Google Landmarks Dataset v2。
# 3. 蒐集而來的資料型態為何
# > 答：CSV資料檔與圖片檔。
# 4. 這組資料想解決的問題如何評估
# > 答：使用 Global Average Precision (GAP)；$ GAP = \frac{1}{M}\sum_{i=1}^N P(i) rel(i) $ <br/>
# > where:<br/>
# >
# > $ N $ is the total number of predictions returned by the system, across all queries <br/>
# > $ M $ is the total number of queries with at least one landmark from the training set visible in it (note that some queries may not depict landmarks) <br/>
# > $ P(i) $ is the precision at rank $ i $ <br/>
# > $ rel(i) $ denotes the relevance of prediciton $ i $: it’s 1 if the $ i $-th prediction is correct, and 0 otherwise

# %% [markdown]
# # 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# > 答：若載客數是增加(新客+舊客)會影響到業績是否提升
# > 影響層面：
# > 1.叫車的方式(便利性)：使用APP預約或是路上攔車，是否影響叫車意願。
# > 2.司機服務品質：會影響乘客是否搭乘的意願。
# > 3.品牌識別：對於顧客是否有年著度。
# > 4.路線規劃：是否有合理的路線規劃以最小的距離乘載更多的顧客。
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# > 答：1.問卷調查；2.App叫車紀錄；3.收費紀錄。
# 3. 蒐集而來的資料型態為何
# > 答：問卷為量化資料；App資料與收費紀錄為系統 Raw data，皆是結構化資料。
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# > 答：使用回歸分析，觀察各個各種因素是否與提升業績有正相關。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yhat):
    """
    請完成這個 Function 後往下執行
    """
    ''' y 與 yhat 的資料型態為 numpy.ndarray '''
    
    n = len(y)
    mse = sum((y-yhat)**2)/n
    
    return mse

# %%
def mean_absolute_error(y, yhat):
    ''' y 與 yhat 的資料型態為 numpy.ndarray '''
    
    n=len(y)
    
    mae= sum(np.abs(y-yhat))/n
    
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 237.420
# The Mean absolute error is 12.280
